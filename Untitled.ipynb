# %%
import os

# Change to a different directory (home directory in this example)
home_dir = os.path.expanduser('~')
os.chdir(home_dir)

# Verify the change
print("Current Working Directory:", os.getcwd())
print("Files in the current directory:", os.listdir('.'))
# Out:
# Current Working Directory: /Users/gabriellatjintjelaar
# Files in the current directory: ['.config', 'Music', 'amsterdam_privacy_project.html', '.DS_Store', 'nltk_data', '.CFUserTextEncoding', '.xonshrc', 'Untitled.ipynb', '.zshrc', 'Pictures', 'APP-style.css', '.zsh_history', '.ipython', 'Desktop', 'Library', '.matplotlib', '.lesshst', 'Covid-9-TEAM', '.oracle_jre_usage', 'Zotero', 'Public', '.tcshrc', 'Movies', 'Applications', 'opt', '.Trash', '.ipynb_checkpoints', '.jupyter', 'Documents', 'myenv', '.vscode', '.bash_profile', 'Downloads', '.cache', '.gitconfig', 'untitled.py', '.viminfo', '.zsh_sessions', '.conda']

# %%
script_path = '/Users/gabriellatjintjelaar/bias_mitigation.py'
# %run {script_path}
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'/Users/gabriellatjintjelaar/bias_mitigation.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /var/folders/0c/g_7xb9nd2kz4k7qctz7vj23m0000gn/T/ipykernel_90146/1353932883.py in <module>
# ...
